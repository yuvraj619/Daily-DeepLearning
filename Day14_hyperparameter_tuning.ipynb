# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148           72.0             35    169.5  33.6
# 1            1       85           66.0             29    102.5  26.6
# 2            8      183           64.0             32    169.5  23.3
# 3            1       89           66.0             23     94.0  28.1
# 4            0      137           40.0             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.corr()['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.495990
# BloodPressure               0.174469
# SkinThickness               0.295138
# Insulin                     0.377081
# BMI                         0.315577
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
print(X.shape)
print(y.shape)
# Out:
# (768, 8)
# (768,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X=scaler.fit_transform(X)

# %%
X
# Out:
# array([[ 0.63994726,  0.86462486, -0.03218035, ...,  0.16948251,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.20472661, -0.52812374, ..., -0.84854874,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.01426457, -0.69343821, ..., -1.32847775,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.02224005, -0.03218035, ..., -0.90672195,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14199419, -1.02406713, ..., -0.33953311,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.94195182, -0.19749482, ..., -0.2959032 ,
#         -0.47378505, -0.87137393]], shape=(768, 8))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test , y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input

# %%
model_1=Sequential()
model_1.add(Input(shape=(8,)))
model_1.add(Dense(32,activation='relu'))
model_1.add(Dense(1,activation='sigmoid'))

model_1.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 32)                  │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 321 (1.25 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_1.fit(X_train,y_train,batch_size=32,epochs=100,validation_data=(X_test,y_test))
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.4886 - loss: 0.7305 - val_accuracy: 0.6364 - val_loss: 0.6620
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6319 - loss: 0.6468 - val_accuracy: 0.7532 - val_loss: 0.5893
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7166 - loss: 0.5879 - val_accuracy: 0.7662 - val_loss: 0.5390
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7606 - loss: 0.5463 - val_accuracy: 0.8052 - val_loss: 0.5002
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7785 - loss: 0.5153 - val_accuracy: 0.8182 - val_loss: 0.4734
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7720 - loss: 0.4938 - val_accuracy: 0.8182 - val_loss: 0.4524
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7801 - loss: 0.4771 - val_accuracy: 0.8117 - val_loss: 0.4370
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7818 - loss: 0.4651 - val_accuracy: 0.8182 - val_loss: 0.4274
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7866 - loss: 0.4542 - val_accuracy: 0.8117 - val_loss: 0.4192
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7899 - loss: 0.4463 - val_accuracy: 0.8117 - val_loss: 0.4129
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7899 - loss: 0.4393 - val_accuracy: 0.8052 - val_loss: 0.4063
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7866 - loss: 0.4339 - val_accuracy: 0.8052 - val_loss: 0.4008
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7899 - loss: 0.4291 - val_accuracy: 0.8182 - val_loss: 0.3969
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7932 - loss: 0.4245 - val_accuracy: 0.8117 - val_loss: 0.3935
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7997 - loss: 0.4212 - val_accuracy: 0.8117 - val_loss: 0.3899
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8029 - loss: 0.4173 - val_accuracy: 0.8182 - val_loss: 0.3876
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8029 - loss: 0.4136 - val_accuracy: 0.8247 - val_loss: 0.3854
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8029 - loss: 0.4102 - val_accuracy: 0.8247 - val_loss: 0.3833
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8909 - loss: 0.2984 - val_accuracy: 0.8636 - val_loss: 0.3396
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8893 - loss: 0.2976 - val_accuracy: 0.8636 - val_loss: 0.3399
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8876 - loss: 0.2975 - val_accuracy: 0.8701 - val_loss: 0.3400
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8909 - loss: 0.2971 - val_accuracy: 0.8701 - val_loss: 0.3395
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8925 - loss: 0.2965 - val_accuracy: 0.8701 - val_loss: 0.3401
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8909 - loss: 0.2956 - val_accuracy: 0.8701 - val_loss: 0.3401
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8909 - loss: 0.2959 - val_accuracy: 0.8701 - val_loss: 0.3394
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8925 - loss: 0.2952 - val_accuracy: 0.8701 - val_loss: 0.3411
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8925 - loss: 0.2950 - val_accuracy: 0.8766 - val_loss: 0.3427
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8925 - loss: 0.2943 - val_accuracy: 0.8701 - val_loss: 0.3418
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8941 - loss: 0.2939 - val_accuracy: 0.8701 - val_loss: 0.3415

# %% [markdown]
# ## TO CHECK FOR BEST OPTIMIZER

# %%
# !pip install -U keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras-tuner) (3.15.1)
# Requirement already satisfied: packaging in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras-tuner) (2.34.2)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras-tuner) (1.83.0)
# Requirement already satisfied: protobuf in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras-tuner) (7.35.1)
# Requirement already satisfied: typing-extensions~=4.12 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from grpcio->keras-tuner) (4.16.0)
# Requirement already satisfied: absl-py in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras->keras-tuner) (2.5.0)
# Requirement already satisfied: numpy in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras->keras-tuner) (2.5.1)
# Requirement already satisfied: rich in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras->keras-tuner) (15.0.0)
# Requirement already satisfied: namex in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras->keras-tuner) (3.14.0)
# Requirement already satisfied: optree in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from keras->keras-tuner) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from requests->keras-tuner) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from requests->keras-tuner) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from requests->keras-tuner) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from requests->keras-tuner) (2026.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from rich->keras->keras-tuner) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in D:\Users\HP\anaconda3\envs\dl\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.8-py3-none-any.whl (129 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
#
#    ---------------------------------------- 0/2 [kt-legacy]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    ---------------------------------------- 2/2 [keras-tuner]
#
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5

# %%
import keras_tuner as kt

# %%
def build_model(hp):
    model_2=Sequential()
    model_2=Sequential()
    model_2.add(Input(shape=(8,)))
    model_2.add(Dense(32,activation='relu'))
    model_2.add(Dense(1,activation='sigmoid'))

    optimizer=hp.Choice('optimizer',values=['adam','sgd','adadelta','rmsprop'])
    
    model_2.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

    return model_2

# %%
tuner=kt.RandomSearch(build_model,objective='val_accuracy',max_trials=5)

# %%
tuner.search(X_train,y_train,epochs=5,validation_data=[X_test,y_test])
